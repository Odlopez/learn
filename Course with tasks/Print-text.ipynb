# %%
from matplotlib.patches import Path, PathPatch
import matplotlib.pyplot as plt

INDENT = 1
ROW_HEIGHT = 6
start_y = 1
start_x = 1
field_height = 8

def make_letter(ax, vertices, codes):
    path = Path(vertices, codes)
    path_patch = PathPatch(path, lw=0, fc='pink')
    ax.add_patch(path_patch)
    
    
def transform_vertices(start_x, start_y, verticles):
    res = []
    for it in verticles:
        res.append((it[0] + start_x, it[1] + start_y))
    return res


def get_length(word):
    res = 0
    for let in word:
        if not letter_data.get(let):
            continue
        res += letter_data[let]['width']
        
    return res


def set_ylim(words):
    global field_height, start_y
    field_height = len(words) * ROW_HEIGHT + (len(words) + 1) * INDENT
    start_y = field_height - INDENT - ROW_HEIGHT
    plt.ylim(0, field_height)
    
    
def set_xlim(words):
    max_word = list(sorted(words, key=lambda x: get_length(x), reverse=True))[0]
    lim = len(max_word) + 1
    
    for let in max_word:
        if not letter_data.get(let):
            continue
        lim += letter_data[let]['width']
        
    plt.xlim(0, lim)

def create_field(words):
    set_xlim(words)
    set_ylim(words)
    
       
def print_word(word):
    global start_x, start_y
    for l in word:
        if not letter_data.get(l):
            print(f'Кажется, я еще не умею рисовать такой символ.( - "{l}"')
            continue
        vertices = transform_vertices(start_x, start_y, letter_data[l]['vertices'])
        codes = letter_data[l]['codes']
        make_letter(ax, vertices, codes)
        start_x += letter_data[l]['width'] + INDENT
        
    start_y -= (INDENT + ROW_HEIGHT)
    start_x = 1
    
letter_data = {
    'а': {
        'vertices': [(0,0), (2,6), (3,6), (5,0), (4,0), (3,1), (3,2), (2.5,4), (2,2), (3,2), (3,1), (2,1), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 5
    },
    'б': {
        'vertices': [(0,0), (0,6), (3,6), (3,5), (1,5), (1,3), (3,3), (3,0), (2,0), (2,1), (2,2), (1,2), (1,1), (2,1), (2,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'в': {
        'vertices': [(0,0), (0,6), (2,6), (3,5.5), (3,5), (2,5), (1,5), (1,4), (2,4), (2,5), (3,5), (3,3.5), (2,3), (3,2.5), (3,2), (2,2), (1,2), (1,1), (2,1), (2,2), (3,2), (3,0.5), (2,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'г': {
        'vertices': [(0,0), (0,6), (3,6), (3,5), (1,5), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'д': {
        'vertices': [(0,0), (0,1), (1,2), (1,6), (4,6), (4,2), (3,2), (3,5), (2,5), (2,2), (3,2), (4,2), (5,1), (5,0), (4,0), (4,1), (1,1), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 5
    },
    'е': {
        'vertices': [(0,0), (0,6), (3,6), (3,5), (1,5), (1,3.5), (3,3.5), (3,2.5), (1,2.5), (1,1), (3,1), (3,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,],
        'width': 3
    },
    'ё': {
        'vertices': [(0,0), (0,6), (3,6), (3,5), (1,5), (1,3.5), (3,3.5), (3,2.5), (1,2.5), (1,1), (3,1), (3,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,],
        'width': 3
    },
    'ж': {
        'vertices': [(0,0), (1,3), (0,6), (1,6), (2,4), (2,6), (3,6), (3,4), (4,6), (5,6), (4,3), (5,0), (4,0), (3,2), (3,0), (2,0), (2,2), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 5
    },
    'з': {
        'vertices': [(0,0), (0,1), (1,1), (2,0.5), (2,2), (1,2.5), (1,3.5), (2,4), (2,5.5), (1,5), (0,5), (0,6), (3,6), (3,3.5), (2,3), (3,2.5), (3,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'й': {
        'vertices': [(0,0), (0,6), (1,6), (1,1), (3,6), (2.5,6), (1.5,6), (1.5,5.5), (2.5,5.5), (2.5,6), (3,6), (4,6), (4,0), (3,0), (3,4), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'и': {
        'vertices': [(0,0), (0,6), (1,6), (1,1), (3,6), (4,6), (4,0), (3,0), (3,4), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'к': {
        'vertices': [(0,0), (0,6), (1,6), (1,4), (3,6), (4,6), (1,3), (4,0), (3,0), (1,2), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'л': {
        'vertices': [(0,0), (2,6), (4,6), (4,0), (3,0), (3,5), (2.5,5), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'м': {
        'vertices': [(0,0), (0,6), (1,6), (3,3), (5,6), (6,6), (6,0), (5,0), (5,4), (3,2), (1,4), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 6
    },
    'н': {
        'vertices': [(0,0), (0,6), (1,6), (1,3.5), (3,3.5), (3,6), (4,6), (4,0), (3,0), (3,2.5), (1,2.5), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'о': {
        'vertices': [(1,0), (0,1), (0,5), (1,6), (2,6), (3,5), (3,1), (2,0), (2,1), (2,5), (1,5), (1,1), (2,1), (2,0), (1,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'п': {
        'vertices': [(0,0), (0,6), (4,6), (4,0), (3,0), (3,5), (1,5), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'р': {
        'vertices': [(0,0), (0,6), (2,6), (3,5), (2,5), (1,5), (1,4), (2,4), (2,5), (3,5), (3,4), (2,3), (1,3), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'с': {
        'vertices': [(0,1), (0,5), (1,6), (3,6), (4,5), (4,4), (3,4), (2.5,5), (1,5), (1,1), (2.5,1), (3,2), (4,2), (4,1), (3,0), (1,0), (0,1)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'т': {
        'vertices': [(0,5), (0,6), (5,6), (5,5), (3,5), (3,0), (2,0), (2,5), (0,5)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 5
    },
    'у': {
        'vertices': [(0,6), (1,6), (2.5,3.5), (3,6), (4,6), (2,0), (1,0), (2,2.5), (0,6)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'ф': {
        'vertices': [(1.5,0), (1.5,3), (1,3), (0,4), (0,5), (1,6), (1,4), (1.5,4), (1.5,5), (1,5), (1,6), (2.5,6), (2.5,4), (3,4), (3,5), (2.5,5), (2.5,6), (3,6), (4,5), (4,4), (3,3), (2.5,3), (2.5,0), (1.5,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'х': {
        'vertices': [(0,0), (1,3), (0,6), (1,6), (2,3), (3,6), (4,6), (3,3), (4,0), (3,0), (2,3), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'ц': {
        'vertices': [(0,0), (0,6), (1,6), (1,1), (3,1), (3,6), (4,6), (4,1), (5,1), (5,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 5
    },
    'ч': {
        'vertices': [(0,3), (0,6), (1,6), (1,4), (2,4), (2,6), (3,6), (3,0), (2,0), (2,3), (0,3)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'ш': {
        'vertices': [(0,0), (0,6), (1,6), (1,1), (2,1), (2,4), (3,4), (3,1), (4,1), (4,6), (5,6), (5,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 5
    },
    'щ': {
        'vertices': [(0,0), (0,6), (1,6), (1,1), (2,1), (2,4), (3,4), (3,1), (4,1), (4,6), (5,6), (5,1), (6,1), (6,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 6
    },
    'ъ': {
        'vertices': [(0,5), (0,6), (2,6), (2,3), (4,3), (4,2), (3,2), (2,2), (2,1), (3,1), (3,2), (4,2), (4,0), (1,0), (1,5), (0,5)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 4
    },
    'ы': {
        'vertices': [(0,0), (0,6), (1,6), (1,3), (3,3), (3,2), (2,2), (1,2), (1,1), (2,1), (2,2), (3,2), (3,0), (0,0), (4,0), (4,6), (5,6), (5,0), (4,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2],
        'width': 5
    },
    'ь': {
        'vertices': [(0,0), (0,6), (1,6), (1,3), (3,3), (3,2), (2,2), (1,2), (1,1), (2,1), (2,2), (3,2), (3,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'э': {
        'vertices': [(0,0), (0,1), (2,1), (2,2.5), (1,2.5), (1,3.5), (2,3.5), (2,5), (0,5), (0,6), (2,6), (3,5), (3,1), (2,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    },
    'ю': {
        'vertices': [(0,0), (0,6), (1,6), (1,3.5), (2,3.5), (2,5), (3,6), (4,6), (5,5), (5,4), (4,4), (3,4), (3,2), (4,2), (4,4), (5,4), (5,1), (4,0), (3,0), (2,1), (2,2.5), (1,2.5), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 5
    },
    'я': {
        'vertices': [(0,0), (1,2), (0,3), (0,5), (1,6), (3,6), (3,5), (2,5), (1,5), (1,3), (2,3), (2,5), (3,5), (3,0), (2,0), (2,2), (1,0), (0,0)],
        'codes': [1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2],
        'width': 3
    }
}


ax = plt.gca()
print('Привет! Я, хоть и бесполезная программа, но умею рисовать то, что Вы напишите!\n')
print('К сожалению, пока что я научилась рисовать только кириллические символы\n')
print('Сейчас Вам будет предложено напечатать какой-то текст. Приготовтесь!\n')
print('Поехали!')

words = [i.lower() for i in input('Что нарисуем?: ').split()]

create_field(words)

for w in words:
    print_word(w)

plt.axis('off')
plt.show()
# Out:
# Привет! Я, хоть и бесполезная программа, но умею рисовать то, что Вы напишите!
#
# К сожалению, пока что я научилась рисовать только кириллические символы
#
# Сейчас Вам будет предложено напечатать какой-то текст. Приготовтесь!
#
# Поехали!
# Что нарисуем?: Сашка занимался весь день какой-то фигней
# Кажется, я еще не умею рисовать такой символ.( - "-"
